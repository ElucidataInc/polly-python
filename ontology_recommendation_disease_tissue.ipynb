# %% [markdown]
# <a href="https://polly.elucidata.io/manage/workspaces?action=open_polly_notebook&amp;source=github&amp;path=ElucidataInc%2Fpolly-python%2Fblob%2Fmain%2Fontology_recommendation_disease_tissue.ipynb&amp;kernel=elucidata%2FPython+3&amp;machine=medium" target="_parent"><img alt="Open in Polly" src="https://elucidatainc.github.io/PublicAssets/open_polly.svg"/></a>

# %% [markdown]
# # Ontology recommendations for disease and tissue using polly-python

# %% [markdown]
# Term expansion functionality for disease and tissue to be added in Polly-Python. This notebook is a playground to test the functionality. The users would now be able to call a function - 'recommend' on disease and tissue column of meta data.
#
# Usage of 'recommend' function -
#
# recommend(field_name, search_term, key - ['match' | 'related'])
#
# field_name -> It can take value: disease, tissue, curated_disease, curated_tissue based on V1 or V2 APIs.
#
# search_term -> Disease or tissue name for which recommendations are required.
#
# key -> Can be "match" or "related"
#
#     match - Only the terms that have an exact match of the keyword in them will be returned as an output.
#
#     related - The list of expanded terms would contain the matched terms, the synonyms, and hypernyms of the keyword as per MeSH ontology.

# %% [markdown]
# ## For users querying V1 infrastructure

# %% [markdown]
# For 'match' query in disease -
#
# query = """SELECT * FROM geo.datasets
#             WHERE disease IN recommend('disease', obesity', 'match')"""
#
# For 'related' query in tissue -
#
# query = """SELECT * FROM geo.datasets
#             WHERE tissue IN recommend('tissue', 'lung', 'related')"""

# %% [markdown]
# ## For users querying V2 infrastructure

# %% [markdown]
# For 'match' query in disease -
#
# query = """SELECT * FROM geo.datasets WHERE CONTAINS(curated_disease, recommend('curated_disease', 'breast neoplasms', 'match'))"""
#
# For 'related' query in tissue -
#
# query = """SELECT * FROM geo.datasets WHERE CONTAINS(curated_tissue, recommend( 'curated_tissue', 'liver', 'match'))"""

# %%
# please do not modify
from IPython.display import display_html
def restartkernel() :
    display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)

# %% [markdown]
# # Import polly-python

# %%
pip install polly-python --user  #Restart kernel after the cell executes.
# Out:
# WARNING: The directory '/home/polly/.cache/pip/http' or its parent directory is not owned by the current user and the cache has been disabled. Please check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# WARNING: The directory '/home/polly/.cache/pip' or its parent directory is not owned by the current user and caching wheels has been disabled. check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# Collecting polly-python
#   Downloading https://files.pythonhosted.org/packages/43/6b/1d9ae3d7941d65e8dd24becca436f52d788eb7383000179fb289297bd849/polly_python-0.0.10-py3-none-any.whl
# Collecting urllib3==1.26.6 (from polly-python)
#   Downloading https://files.pythonhosted.org/packages/5f/64/43575537846896abac0b15c3e5ac678d787a4021e906703f1766bfb8ea11/urllib3-1.26.6-py2.py3-none-any.whl (138kB)
#      |################################| 143kB 10.0MB/s eta 0:00:01
# Requirement already satisfied: botocore>=1.20.73 in /usr/local/lib/python3.6/dist-packages (from polly-python) (1.20.112)
# Requirement already satisfied: python-dateutil==2.8.1 in /usr/local/lib/python3.6/dist-packages (from polly-python) (2.8.1)
# Collecting python-magic==0.4.24 (from polly-python)
#   Downloading https://files.pythonhosted.org/packages/d3/99/c89223c6547df268596899334ee77b3051f606077317023617b1c43162fb/python_magic-0.4.24-py2.py3-none-any.whl
# Collecting boto3>=1.17.73 (from polly-python)
#   Downloading https://files.pythonhosted.org/packages/9b/5e/12e50157795274dad90bbecbfe6c3283ecbdb9096462df0cc5cb30dca0ab/boto3-1.21.45-py3-none-any.whl (132kB)
#      |################################| 133kB 91.5MB/s eta 0:00:01
# Collecting cmapPy (from polly-python)
#   Downloading https://files.pythonhosted.org/packages/e8/e1/9e90b0dc2051f4a3a2b9553b254889e93a2a3c7a3b925433c6298d99d596/cmapPy-4.0.1-py2.py3-none-any.whl (150kB)
#      |################################| 153kB 97.5MB/s eta 0:00:01
# Collecting black (from polly-python)
#   Downloading https://files.pythonhosted.org/packages/2e/ef/a38a2189959246543e60859fb65bd3143129f6d18dfc7bcdd79217f81ca2/black-22.3.0-py3-none-any.whl (153kB)
#      |################################| 163kB 99.6MB/s eta 0:00:01
# Requirement already satisfied: Cerberus==1.3.2 in /usr/local/lib/python3.6/dist-packages/Cerberus-1.3.2-py3.6.egg (from polly-python) (1.3.2)
# Collecting joblib (from polly-python)
#   Downloading https://files.pythonhosted.org/packages/3e/d5/0163eb0cfa0b673aa4fe1cd3ea9d8a81ea0f32e50807b0c295871e4aab2e/joblib-1.1.0-py2.py3-none-any.whl (306kB)
#      |################################| 307kB 9.6MB/s eta 0:00:01
# Collecting requests==2.25.1 (from polly-python)
#   Downloading https://files.pythonhosted.org/packages/29/c1/24814557f1d22c56d50280771a17307e6bf87b70727d975fd6b2ce6b014a/requests-2.25.1-py2.py3-none-any.whl (61kB)
#      |################################| 61kB 61.8MB/s eta 0:00:01
# Collecting retrying==1.3.3 (from polly-python)
#   Downloading https://files.pythonhosted.org/packages/44/ef/beae4b4ef80902f22e3af073397f079c96969c69b2c7d52a57ea9ae61c9d/retrying-1.3.3.tar.gz
# Collecting elucidatacloudpathlib==0.6.6 (from polly-python)
#   Downloading https://files.pythonhosted.org/packages/b1/d6/5162b68817dd93130dc9421f23a299ee6b243c0ff8a806370727ff10090f/elucidatacloudpathlib-0.6.6-py3-none-any.whl (50kB)
#      |################################| 51kB 48.4MB/s eta 0:00:01
# Collecting idna==2.10 (from polly-python)
#   Downloading https://files.pythonhosted.org/packages/a2/38/928ddce2273eaa564f6f50de919327bf3a00f091b5baba8dfa9460f3a8a8/idna-2.10-py2.py3-none-any.whl (58kB)
#      |################################| 61kB 39.7MB/s eta 0:00:01
# Collecting Deprecated (from polly-python)
#   Downloading https://files.pythonhosted.org/packages/51/6a/c3a0408646408f7283b7bc550c30a32cc791181ec4618592eec13e066ce3/Deprecated-1.2.13-py2.py3-none-any.whl
# Collecting chardet==4.0.0 (from polly-python)
#   Downloading https://files.pythonhosted.org/packages/19/c7/fa589626997dd07bd87d9269342ccb74b1720384a4d739a1872bd84fbe68/chardet-4.0.0-py2.py3-none-any.whl (178kB)
#      |################################| 184kB 93.9MB/s eta 0:00:01
# Collecting pytz==2021.1 (from polly-python)
#   Downloading https://files.pythonhosted.org/packages/70/94/784178ca5dd892a98f113cdd923372024dc04b8d40abe77ca76b5fb90ca6/pytz-2021.1-py2.py3-none-any.whl (510kB)
#      |################################| 512kB 90.1MB/s eta 0:00:01
# Collecting six==1.16.0 (from polly-python)
#   Downloading https://files.pythonhosted.org/packages/d9/5a/e7c31adbe875f2abbb91bd84cf2dc52d792b5a01506781dbcf25c91daf11/six-1.16.0-py2.py3-none-any.whl
# Collecting certifi==2021.10.8 (from polly-python)
#   Downloading https://files.pythonhosted.org/packages/37/45/946c02767aabb873146011e665728b680884cd8fe70dde973c640e45b775/certifi-2021.10.8-py2.py3-none-any.whl (149kB)
#      |################################| 153kB 96.1MB/s eta 0:00:01
# Collecting postpy2==0.0.6 (from polly-python)
#   Downloading https://files.pythonhosted.org/packages/7e/25/d98f5ea87d937bf44963be78b504dbb3ddea1c6ddfcc0985b02d062b41dd/postpy2-0.0.6-py3-none-any.whl
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from polly-python) (1.0.1)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from botocore>=1.20.73->polly-python) (0.9.5)
# Collecting s3transfer<0.6.0,>=0.5.0 (from boto3>=1.17.73->polly-python)
#   Downloading https://files.pythonhosted.org/packages/7b/9c/f51775ebe7df5a7aa4e7c79ed671bde94e154bd968aca8d65bb24aba0c8c/s3transfer-0.5.2-py3-none-any.whl (79kB)
#      |################################| 81kB 72.0MB/s eta 0:00:01
# Collecting h5py>=2.6.0 (from cmapPy->polly-python)
#   Downloading https://files.pythonhosted.org/packages/70/7a/e53e500335afb6b1aade11227cdf107fca54106a1dca5c9d13242a043f3b/h5py-3.1.0-cp36-cp36m-manylinux1_x86_64.whl (4.0MB)
#      |################################| 4.0MB 93.6MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.11.2 in /usr/local/lib/python3.6/dist-packages (from cmapPy->polly-python) (1.18.1)
# Collecting pathspec>=0.9.0 (from black->polly-python)
#   Downloading https://files.pythonhosted.org/packages/42/ba/a9d64c7bcbc7e3e8e5f93a52721b377e994c22d16196e2b0f1236774353a/pathspec-0.9.0-py2.py3-none-any.whl
# Collecting typing-extensions>=3.10.0.0; python_version < "3.10" (from black->polly-python)
#   Downloading https://files.pythonhosted.org/packages/45/6b/44f7f8f1e110027cf88956b59f2fad776cca7e1704396d043f89effd3a0e/typing_extensions-4.1.1-py3-none-any.whl
# Collecting dataclasses>=0.6; python_version < "3.7" (from black->polly-python)
#   Downloading https://files.pythonhosted.org/packages/fe/ca/75fac5856ab5cfa51bbbcefa250182e50441074fdc3f803f6e76451fab43/dataclasses-0.8-py3-none-any.whl
# Collecting mypy-extensions>=0.4.3 (from black->polly-python)
#   Downloading https://files.pythonhosted.org/packages/5c/eb/975c7c080f3223a5cdaff09612f3a5221e4ba534f7039db34c35d95fa6a5/mypy_extensions-0.4.3-py2.py3-none-any.whl
# Collecting tomli>=1.1.0; python_version < "3.11" (from black->polly-python)
#   Downloading https://files.pythonhosted.org/packages/05/e4/74f9440db36734d7ba83c574c1e7024009ce849208a41f90e94a134dc6d1/tomli-1.2.3-py3-none-any.whl
# Collecting typed-ast>=1.4.2; python_version < "3.8" and implementation_name == "cpython" (from black->polly-python)
#   Downloading https://files.pythonhosted.org/packages/e2/dc/40caedf9512442b173cc4b7add05fe82852fa4e4eddf6c1865aecee10474/typed_ast-1.5.3-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (831kB)
#      |################################| 839kB 99.8MB/s eta 0:00:01
# Collecting platformdirs>=2 (from black->polly-python)
#   Downloading https://files.pythonhosted.org/packages/b1/78/dcfd84d3aabd46a9c77260fb47ea5d244806e4daef83aa6fe5d83adb182c/platformdirs-2.4.0-py3-none-any.whl
# Collecting click>=8.0.0 (from black->polly-python)
#   Downloading https://files.pythonhosted.org/packages/4a/a8/0b2ced25639fb20cc1c9784de90a8c25f9504a7f18cd8b5397bd61696d7d/click-8.0.4-py3-none-any.whl (97kB)
#      |################################| 102kB 78.3MB/s ta 0:00:01
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from Cerberus==1.3.2->polly-python) (45.2.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from elucidatacloudpathlib==0.6.6->polly-python) (1.5.0)
# Collecting wrapt<2,>=1.10 (from Deprecated->polly-python)
#   Downloading https://files.pythonhosted.org/packages/ba/8c/3d3dff02ae905157ba417b801f4a7aa4e6fedbc43882e9c765b7aae438ac/wrapt-1.14.0-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (74kB)
#      |################################| 81kB 71.3MB/s eta 0:00:01
# Collecting cached-property; python_version < "3.8" (from h5py>=2.6.0->cmapPy->polly-python)
#   Downloading https://files.pythonhosted.org/packages/48/19/f2090f7dad41e225c7f2326e4cfe6fff49e57dedb5b53636c9551f86b069/cached_property-1.5.2-py2.py3-none-any.whl
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->elucidatacloudpathlib==0.6.6->polly-python) (3.1.0)
# Building wheels for collected packages: retrying
#   WARNING: Building wheel for retrying failed: [Errno 13] Permission denied: '/home/polly/.cache/pip/wheels/d7'
# Failed to build retrying
# ERROR: awscli 1.18.178 has requirement botocore==1.19.18, but you'll have botocore 1.20.112 which is incompatible.
# ERROR: awscli 1.18.178 has requirement s3transfer<0.4.0,>=0.3.0, but you'll have s3transfer 0.5.2 which is incompatible.
# ERROR: boto3 1.21.45 has requirement botocore<1.25.0,>=1.24.45, but you'll have botocore 1.20.112 which is incompatible.
# Installing collected packages: urllib3, python-magic, s3transfer, boto3, cached-property, h5py, six, idna, chardet, certifi, requests, cmapPy, pathspec, typing-extensions, dataclasses, mypy-extensions, tomli, typed-ast, platformdirs, click, black, joblib, retrying, elucidatacloudpathlib, wrapt, Deprecated, pytz, postpy2, polly-python
#   Running setup.py install for retrying ... done
# Successfully installed Deprecated-1.2.13 black-22.3.0 boto3-1.21.45 cached-property-1.5.2 certifi-2021.10.8 chardet-4.0.0 click-8.0.4 cmapPy-4.0.1 dataclasses-0.8 elucidatacloudpathlib-0.6.6 h5py-3.1.0 idna-2.10 joblib-1.1.0 mypy-extensions-0.4.3 pathspec-0.9.0 platformdirs-2.4.0 polly-python-0.0.10 postpy2-0.0.6 python-magic-0.4.24 pytz-2021.1 requests-2.25.1 retrying-1.3.3 s3transfer-0.5.2 six-1.16.0 tomli-1.2.3 typed-ast-1.5.3 typing-extensions-4.1.1 urllib3-1.26.6 wrapt-1.14.0
# WARNING: You are using pip version 19.2.3, however version 21.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
restartkernel() #Pause for a few seconds before the kernel is refreshed
# Out:
# <script>Jupyter.notebook.kernel.restart()</script>

# %% [markdown]
# # Import Dependencies

# %%
import os
from polly.auth import Polly
from polly.omixatlas import OmixAtlas

# %% [markdown]
# # Auth With Token on Polly

# %%
POLLY_REFRESH_TOKEN = os.environ['POLLY_REFRESH_TOKEN']
client = OmixAtlas(POLLY_REFRESH_TOKEN)

# %% [markdown]
# # Util Functions. [Execute following code before using recommend function]

# %%
import re

REGEX_STRING = "recommend\s*\(\s*'(.*?)',\s*'(.*?)',\s*'(.*?)'\)"

def get_recommendation_list(sql_query):
    recommendation_list = re.findall(REGEX_STRING, sql_query)
    if recommendation_list:
        return recommendation_list
    else:
        return []


def get_index(sql_query):
    index = re.search(r"[a-z_+]*.datasets", sql_query)
    if index:
        index = index.group().split('.')[0]
    return index

def process_result(result, keyword):
    related_terms = [bucket["key"] for bucket in result["data"]["aggregations"]["related_terms"]["buckets"] ]
    auto_complete = [bucket["key"] for bucket in result["data"]["aggregations"]["auto_complete"]["buckets"] ]
    if keyword == 'match':
        return auto_complete
    else:
        return list(set(related_terms)|set(auto_complete))
    
def get_expanded_result(recommendation_list, index):
    expanded_result = []
    dis_tis_mappings = {
        "curated_disease": "disease",
        "disease": "disease",
        "curated_tissue" : "tissue",
        "tissue" : "tissue"
    }
    for recommendations in recommendation_list:
        dis_tis = dis_tis_mappings[recommendations[0]]
        term = recommendations[1]
        keyword = recommendations[2]
        
        repo_id = library_client.get_index_id(index)
        result = library_client.autocomplete(repo_id, term, field = dis_tis)
        result = process_result(result, keyword)
        expanded_result.append(result)
    return expanded_result

def edit_query(sql_query, expanded_result):
    edited_query = sql_query
    for result in expanded_result:
        result_string = "(" + ', '.join(f"'{w}'" for w in result) + ")"
        edited_query = re.sub(REGEX_STRING, result_string, edited_query, 1)
    return edited_query

def edit_v2_query(sql_query, expanded_result, recommendation_list):
    CONTAINS_REGEX_STRING = "(?i)CONTAINS\s*\(\s*(curated_disease|curated_tissue)\s*,\s*recommend\s*\(\s*'(.*?)',\s*'(.*?)',\s*'(.*?)'\s*\)\s*\)"
    edited_query = sql_query
    for i, zipped_result in enumerate(zip(expanded_result, recommendation_list)):
        result_string = '('
        expanded_terms = zipped_result[0]
        recommend = zipped_result[1]
        key = recommend[0]
        
        for i, term in enumerate(expanded_terms):
            if (recommend[0] == 'curated_disease'):
                term = term.title()
            result_string = result_string + 'CONTAINS(' + key + ", '" + term + "')"
            if i != len(expanded_terms) - 1:
                result_string += ' OR '
        result_string += ')'
        edited_query = re.sub(CONTAINS_REGEX_STRING, result_string, edited_query, 1)
        
    return edited_query

def recommend(sql_query, api_version='v2'):
    recommendation_list = get_recommendation_list(sql_query)
    if (len(recommendation_list) == 0):
        return sql_query
    index = get_index(sql_query)
    if not index:
        return sql_query
    expanded_result = get_expanded_result(recommendation_list, index)
    edited_query = ''
    if (api_version == 'v1'):
        edited_query = edit_query(sql_query, expanded_result)
    else:
        edited_query = edit_v2_query(sql_query, expanded_result, recommendation_list)
    return edited_query

# %%
from requests import Session
import json
import ssl
import logging
import os
import platform
import tempfile
from pathlib import Path
from typing import Union, Dict
from collections import namedtuple
import pandas as pd
import requests
from retrying import retry

from polly import constants as const

from polly import helpers
from polly.auth import Polly
from polly.constants import DATA_TYPES
from polly.errors import (
    QueryFailedException,
    UnfinishedQueryException,
    InvalidParameterException,
    error_handler,
    is_unfinished_query_error,
    paramException,
    wrongParamException,
    apiErrorException,
    invalidApiResponseException,
)
from deprecated import deprecated
from polly.index_schema_level_conversion_const import indexes_schema_level_map

QUERY_API_V1 = "v1"
QUERY_API_V2 = "v2"

class PollySession(Session):
    def __init__(self, REFRESH_TOKEN):
        Session.__init__(self)
        self.headers = {
            "Content-Type": "application/vnd.api+json",
            "Cookie" : f"refreshToken={REFRESH_TOKEN}",
            "User-Agent" : "polly-python/"
        }


class OmixAtlas_autoComplete:
    polly_api_url= {"dev":"dev","test":"test","prod":""}
    repo_index_id = {'gdx_files': 1646370413059, 'auron_data_lake_files': 1613041985263, 'hpa_files': 1619514006627, 'teddy_files': 1615464367934, 'valo_onco_files': 1649184014614, 'gdc_files': 1623221686703, 'geo_files': 9, 'rcsb_structures_files': 1639402777465, 'auron_single_cell_atlas_files': 1649415790935, 'enterprise_atlas_files': 1638441282192, 'cptac_files': 1609924165364, 'liveromix_atlas_files': 1615965444377, 'cbioportal_files': 1623986995264, 'depmap_files': 1612338998334, 'pcd_files': 1622113130397, 'lincs_files': 32, 'metabolomics_files': 23, 'immport_files': 1621422280385, 'transcriptomics__cyt_files': 1612862450692, 'ukbiobank_files': 1638762466067, 'exelixis_files': 1649172174566, 'bbio_files': 1647250357385, 'sc_data_lake_files': 17, 'tcga_files': 15, 'etx_files': 1641883311001, 'ngj_files': 1618578954468, 'gtex_files': 14, 'gnomad_files': 1628836648493, 'geo_raw_counts_files': 1647341066415}
    
    def __init__(self, token: str, polly_env) -> None:
        self.session = PollySession(token)
        self.base_url = "https://v2.api.{}polly.elucidata.io/v1/omixatlases".format(self.polly_api_url[polly_env])
        self.omixatlas_base_url = f"https://v2.api.{self.polly_api_url[polly_env]}polly.elucidata.io"

    def get_all_omixatlas(self):
        url = self.base_url
        params = {"summarize": "true"}
        response = self.session.get(url,params=params)
        return response.json()

    def omixatlas_summary(self, key: str):
        url = f"{self.base_url}/{key}"
        params = {"summarize": "true"}
        response = self.session.get(url,params=params)
        error_handler(response)
        return response.json()

    def autocomplete(self,atlas_id, keyword =None, field=None, put_synonyms = None):
        url = f"{self.base_url}/{atlas_id}/autocomplete"
        payload = {"data":{"attributes":{},"type":"omixatlases"}}
        if keyword is not None:
            payload["data"]["attributes"].update({"keyword":keyword})
        if field is not None:
            payload["data"]["attributes"].update({"field":field})
        if put_synonyms is not None:
            payload["data"]["attributes"].update({"put_synonyms":put_synonyms})
        response = self.session.post(url,json=payload)
        message = response.json().get('message', None)
        if message is not None:
            print(message)
        return self.__process_query_response(response.json())


    def __process_query_response(self, response: dict):
        response.pop("took", None)
        response.pop("timed_out", None)
        response.pop("_shards", None)
        processed_response = None
        try:
            hits = response.get('hits').get('hits')
            if hits:
                processed_response = pd.DataFrame(hits)
            else:
                response.pop('hits', None)
                processed_response = response
        except AttributeError:
            processed_response = response
        return processed_response 

    def get_index_id(self, index):
        index = index + "_files"
        return self.repo_index_id[index]
    
    def query_metadata(
        self,
        query: str,
        experimental_features=None,
        query_api_version=QUERY_API_V2,
        page_size=None,  # Note: do not increase page size more than 999
    ):
        max_page_size = 999
        if page_size is not None and page_size > max_page_size:
            raise ValueError(
                f"The maximum permitted value for page_size is {max_page_size}"
            )
        elif page_size is None and query_api_version != QUERY_API_V2:
            page_size = 500

        query = recommend(query, query_api_version)
        print(query)
        queries_url = f"{self.base_url}/queries"
        queries_payload = {
            "data": {
                "type": "queries",
                "attributes": {"query": query, "query_api_version": query_api_version},
            }
        }
        if experimental_features is not None:
            queries_payload.update({"experimental_features": experimental_features})

        response = self.session.post(queries_url, json=queries_payload)
        error_handler(response)

        query_data = response.json().get("data")
        query_id = query_data.get("id")
        return self._process_query_to_completion(query_id, query_api_version, page_size)

    @retry(
        retry_on_exception=is_unfinished_query_error,
        wait_exponential_multiplier=500,  # Exponential back-off starting 500ms
        wait_exponential_max=10000,  # After 10s, retry every 10s
        stop_max_delay=300000,  # Stop retrying after 300s (5m)
    )
    def _process_query_to_completion(
        self, query_id: str, query_api_version: str, page_size: Union[int, None]
    ):
        queries_url = f"{self.base_url}/queries/{query_id}"
        response = self.session.get(queries_url)
        error_handler(response)

        query_data = response.json().get("data")
        query_status = query_data.get("attributes", {}).get("status")
        if query_status == "succeeded":
            return self._handle_query_success(query_data, query_api_version, page_size)
        elif query_status == "failed":
            self._handle_query_failure(query_data)
        else:
            raise UnfinishedQueryException(query_id)

    def _handle_query_failure(self, query_data: dict):
        fail_msg = query_data.get("attributes").get("failure_reason")
        raise QueryFailedException(fail_msg)

    def _handle_query_success(
        self, query_data: dict, query_api_version: str, page_size: Union[int, None]
    ) -> pd.DataFrame:
        query_id = query_data.get("id")

        details = []
        time_taken_in_ms = query_data.get("attributes").get("exec_time_ms")
        if isinstance(time_taken_in_ms, int):
            details.append("time taken: {:.2f} seconds".format(time_taken_in_ms / 1000))
        data_scanned_in_bytes = query_data.get("attributes").get("data_scanned_bytes")
        if isinstance(data_scanned_in_bytes, int):
            details.append(
                "data scanned: {:.3f} MB".format(data_scanned_in_bytes / (1024**2))
            )

        if details:
            detail_str = ", ".join(details)
            print("Query execution succeeded " f"({detail_str})")
        else:
            print("Query execution succeeded")

        if query_api_version != QUERY_API_V2 or page_size is not None:
            return self._fetch_results_as_pages(query_id, page_size)
        else:
            return self._fetch_results_as_file(query_id)

    def _fetch_results_as_pages(self, query_id, page_size):
        first_page_url = (
            f"{self.base_url}/queries/{query_id}" f"/results?page[size]={page_size}"
        )
        response = self.session.get(first_page_url)
        error_handler(response)
        result_data = response.json()
        rows = [row_data.get("attributes") for row_data in result_data.get("data")]

        all_rows = rows

        message = "Fetched {} rows"
        print(message.format(len(all_rows)), end="\r")

        while (
            result_data.get("links") is not None
            and result_data.get("links").get("next") is not None
            and result_data.get("links").get("next") != "null"
        ):
            next_page_url = self.omixatlas_base_url + result_data.get("links").get("next")
            response = self.session.get(next_page_url)
            error_handler(response)
            result_data = response.json()
            if result_data.get("data"):
                rows = [
                    row_data.get("attributes") for row_data in result_data.get("data")
                ]
            else:
                rows = []
            all_rows.extend(rows)
            print(message.format(len(all_rows)), end="\r")

        # Blank line resets console line start position
        print()

        return pd.DataFrame(all_rows)

    def _fetch_results_as_file(self, query_id):
        results_file_req_url = (
            f"{self.base_url}/queries/{query_id}/results?action=download"
        )
        response = self.session.get(results_file_req_url)
        error_handler(response)
        result_data = response.json()

        results_file_download_url = result_data.get("data", {}).get("download_url")
        if (
            results_file_download_url is None
            or results_file_download_url == "Not available"
        ):
            # The user is probably executing SHOW TABLES or DESCRIBE query
            return self._fetch_results_as_pages(query_id, 100)

        def _local_temp_file_path(filename):
            temp_dir = Path(
                "/tmp" if platform.system() == "Darwin" else tempfile.gettempdir()
            ).absolute()

            temp_file_path = os.path.join(temp_dir, filename)
            if Path(temp_file_path).exists():
                os.remove(temp_file_path)

            return temp_file_path

        def _download_file_stream(download_url, _local_file_path):
            with requests.get(download_url, stream=True, headers={}) as r:
                r.raise_for_status()
                with open(_local_file_path, "wb") as f:
                    for chunk in r.iter_content(chunk_size=8192):
                        f.write(chunk)

        local_file_path = _local_temp_file_path(f"{query_id}.csv")
        _download_file_stream(results_file_download_url, local_file_path)

        data_df = pd.read_csv(local_file_path)
        print(f"Fetched {len(data_df.index)} rows")

        return data_df


library_client = OmixAtlas_autoComplete(POLLY_REFRESH_TOKEN, polly_env = "prod")

# %% [markdown]
# # Queries for V1 storage infrastructure

# %% [markdown]
# ## Previous query on V1 infrastructure
# Before implementation of this feature, users query for a given tissue and disease as shown below.
#
# As per the output, user is able to fetch only 5 datasets for the given disease and tissue combination.

# %%
sql_query = """SELECT * FROM geo.datasets WHERE disease = 'nephritis' AND tissue = 'kidney' LIMIT 2000"""
result = library_client.query_metadata(query=sql_query, query_api_version="v1")
result
# Out:
# SELECT * FROM geo.datasets WHERE disease = 'nephritis' AND tissue = 'kidney' LIMIT 2000
# Query execution succeeded
# Fetched 5 rows
#   file_type                                      tissue  \
# 0       gct                                    [kidney]
# 1       gct  [smooth muscle, serum, kidney, hypophysis]
# 2       gct                                    [kidney]
# 3       NaN                                    [kidney]
# 4       gct                             [kidney, serum]
#
#                                              disease          dataset_id  \
# 0                                        [Nephritis]    GSE37402_GPL6246
# 1  [Renal Insufficiency, Nephritis, Cataract, Glo...   GSE69536_GPL10787
# 2  [Proteinuria, Lupus Erythematosus, Systemic, N...    GSE10144_GPL6362
# 3  [Nephritis, Megalocytic interstitial nephritis...     GSE75693_GPL570
# 4  [DNA Repair-Deficiency Disorders, Nephritis, P...  GSE107364_GPL10787
#
#          organism dataset_source    platform  \
# 0  [Mus musculus]            GEO  Microarray
# 1  [Mus musculus]            GEO  Microarray
# 2  [Mus musculus]            GEO  Microarray
# 3  [Homo sapiens]            GEO  Microarray
# 4  [Mus musculus]            GEO  Microarray
#
#                                          description     kw_data_type  \
# 0  PGE2 promotes recovery from established Nephro...  Transcriptomics
# 1  Gene expression profile in kidney with experim...  Transcriptomics
# 2  Spironolactone effect on renal RNA expression ...  Transcriptomics
# 3  Mining the Human Urine Proteome for Monitoring...  Transcriptomics
# 4  NEMO is distinct from IKK2 by regulating non-c...  Transcriptomics
#
#                                         kw_cell_type  ...  \
# 0                                             [None]  ...
# 1                                  [epithelial cell]  ...
# 2                                             [None]  ...
# 3                                               None  ...
# 4  [lymphocyte, T cell, regulatory T cell, T-help...  ...
#
#                                          kw_location   kw_timestamp  \
# 0  https://discover-prod-datalake-v1.s3-us-west-2...  1647615752910
# 1  https://discover-prod-datalake-v1.s3-us-west-2...  1647619035476
# 2  https://discover-prod-datalake-v1.s3-us-west-2...  1647607811106
# 3  https://discover-prod-datalake-v1.s3-us-west-2...  1647619587985
# 4  https://discover-prod-datalake-v1.s3-us-west-2...  1647608599458
#
#                                            kw_smiles publication_name  year  \
# 0                                                NaN              NaN   NaN
# 1  [Nc1ncnc2n(cnc12)[C@@H]1O[C@@H]2COP(O)(=O)O[C@...              NaN   NaN
# 2                                                NaN              NaN   NaN
# 3                                                NaN         27165815  2018
# 4                                                NaN              NaN   NaN
#
#                                            operation is_public  \
# 0                                                NaN       NaN
# 1                                                NaN       NaN
# 2                                                NaN       NaN
# 3  {'is_normalized': 'true', 'batch_corrected_var...      true
# 4                                                NaN       NaN
#
#   data_repository                                        publication    drug
# 0             NaN                                                NaN     NaN
# 1             NaN                                                NaN     NaN
# 2             NaN                                                NaN     NaN
# 3             geo  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...  [None]
# 4             NaN                                                NaN     NaN
#
# [5 rows x 40 columns]

# %% [markdown]
# ## New queries after implementation of ontology recommendations
# Now the users can query as shown below.
#
# As per the output, user is able to fetch only 138 datasets for the given disease and tissue combination.

# %%
sql_query = """SELECT * FROM geo.datasets WHERE disease IN recommend('disease', 'nephritis', 'related') 
                AND tissue IN recommend('tissue', 'kidney', 'related') LIMIT 2000"""
result = library_client.query_metadata(query=sql_query, query_api_version="v1")
result
# Out:
# SELECT * FROM geo.datasets WHERE disease IN ('nephritis, interstitial', 'nephritis', 'pyelonephritis', 'lupus nephritis', 'glomerulosclerosis, focal segmental', 'glomerulonephritis, iga', 'nephritis, hereditary', 'kidney tubular necrosis, acute, nephritis, interstitial', 'granulomatosis with polyangiitis', 'megalocytic interstitial nephritis', 'anti-glomerular basement membrane disease', 'glomerulonephritis, membranoproliferative', 'glomerulonephritis, membranous', 'nephrosis, lipoid', 'glomerulonephritis')
#                 AND tissue IN ('renal tubule', 'renal artery', 'renal distal tubule', 'inner medullary collecting duct', 'henles loop', 'renal outer medulla', 'renal papilla', 'renal proximal tubule', 'connecting tubule', 'renal proximal tubule epithelium', 'urine', 'collecting duct', 'cortical collecting duct', 'renal glomerular capsule', 'renal medulla', 'renal parenchyma', 'renal corpuscle', 'nephron', 'tubulointerstitium', 'podocyte', 'kidney', 'renal glomerulus', 'mesangium', 'renal cortex', 'renal inner medulla', 'urinary tract', 'urinary system', 'renal epithelium') LIMIT 2000
# Query execution succeeded
# Fetched 138 rows
#     publication_name                                 tissue dataset_source  \
# 0           28242240                               [kidney]            GEO
# 1           27942582  [blood plasma, renal proximal tubule]            GEO
# 2           27760209                               [kidney]            GEO
# 3           25840911                               [kidney]            GEO
# 4           30514835                               [kidney]            GEO
# ..               ...                                    ...            ...
# 133         28646076                               [kidney]            GEO
# 134             none                         [renal cortex]            GEO
# 135              NaN       [renal glomerulus, skin, kidney]            GEO
# 136         30776024                     [renal glomerulus]            GEO
# 137              NaN                               [kidney]            GEO
#
#                                            description             organism  \
# 0    NorUrsodeoxycholic Acid Ameliorates Cholemic N...       [Mus musculus]
# 1    Transcriptional effects of Pentraxin-2 in fibr...       [Mus musculus]
# 2    Kidney gene expression profiles from a lupus n...       [Mus musculus]
# 3    Macrophage epoxygenase determines a pro-fibrot...  [Rattus norvegicus]
# 4    Human iPSC derived glomeruli facilitate accura...       [Homo sapiens]
# ..                                                 ...                  ...
# 133  Transcriptomic and proteomic profiling reveal ...       [Homo sapiens]
# 134  Global gene expression profiling on renal scar...  [Rattus norvegicus]
# 135  Gene Expression Profiling of Glomeruli from a ...       [Mus musculus]
# 136   Expression data from podocyte injured glomerulus       [Mus musculus]
# 137  Renal circadian rhythm dysregulation in lupus ...       [Mus musculus]
#
#      year                                            disease  \
# 0    2018             [Nephritis, Interstitial, Cholestasis]
# 1    2018  [Nephritis, Hereditary, Renal Insufficiency, C...
# 2    2018                     [Proteinuria, Lupus Nephritis]
# 3    2018                               [Glomerulonephritis]
# 4    2019                  [Glomerulonephritis, Proteinuria]
# ..    ...                                                ...
# 133  2018  [Segmental glomerulosclerosis, Glomerulonephri...
# 134  2018           [Vesico-Ureteral Reflux, Pyelonephritis]
# 135   NaN  [Diffuse Cerebral Sclerosis of Schilder, Glome...
# 136  2018      [Glomerulonephritis, Kidney Failure, Chronic]
# 137   NaN  [Lupus Nephritis, Renal Insufficiency, Protein...
#
#                                              operation    platform  \
# 0    {'is_normalized': 'true', 'batch_corrected_var...  Microarray
# 1    {'is_normalized': 'true', 'batch_corrected_var...  Microarray
# 2    {'is_normalized': 'true', 'batch_corrected_var...  Microarray
# 3    {'is_normalized': 'true', 'batch_corrected_var...      RNASeq
# 4    {'is_normalized': 'true', 'batch_corrected_var...      RNASeq
# ..                                                 ...         ...
# 133  {'is_normalized': 'true', 'batch_corrected_var...  Microarray
# 134  {'is_normalized': 'true', 'batch_corrected_var...  Microarray
# 135                                                NaN  Microarray
# 136  {'is_normalized': 'true', 'batch_corrected_var...  Microarray
# 137                                                NaN  Microarray
#
#              dataset_id  ...   kw_timestamp            author  \
# 0     GSE84584_GPL16570  ...  1647620075138               NaN
# 1      GSE85409_GPL6887  ...  1647620156614               NaN
# 2     GSE86423_GPL11180  ...  1647620245266               NaN
# 3     GSE65715_GPL18694  ...  1647623785117               NaN
# 4     GSE99583_GPL18573  ...  1648049528744  Belinda,,Phipson
# ..                  ...  ...            ...               ...
# 133   GSE93798_GPL22945  ...  1647620645302               NaN
# 134      GSE7087_GPL890  ...  1647619239080               NaN
# 135    GSE18358_GPL1261  ...  1647613538812               NaN
# 136  GSE112116_GPL16570  ...  1647609380875               NaN
# 137   GSE131892_GPL6885  ...  1647611692269               NaN
#
#                                               abstract  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    Podocytes are the highly specialised cells wit...
# ..                                                 ...
# 133                                                NaN
# 134                                                NaN
# 135                                                NaN
# 136                                                NaN
# 137                                                NaN
#
#                                                   type file_type  \
# 0                                                  NaN       NaN
# 1                                                  NaN       NaN
# 2                                                  NaN       NaN
# 3                                                  NaN       NaN
# 4    Expression profiling by high throughput sequen...       NaN
# ..                                                 ...       ...
# 133                                                NaN       NaN
# 134                                                NaN       NaN
# 135                                                NaN      h5ad
# 136                                                NaN       NaN
# 137                                                NaN       NaN
#
#     source_process manually_curated processing drug data_matrix_available
# 0              NaN              NaN        NaN  NaN                   NaN
# 1              NaN              NaN        NaN  NaN                   NaN
# 2              NaN              NaN        NaN  NaN                   NaN
# 3              NaN              NaN        NaN  NaN                   NaN
# 4              NaN              NaN        NaN  NaN                   NaN
# ..             ...              ...        ...  ...                   ...
# 133            NaN              NaN        NaN  NaN                   NaN
# 134            NaN              NaN        NaN  NaN                   NaN
# 135      connector              NaN        NaN  NaN                   NaN
# 136            NaN              NaN        NaN  NaN                   NaN
# 137            NaN              NaN  connector  NaN                   NaN
#
# [138 rows x 46 columns]

# %% [markdown]
# ## Other query examples on V1 infrastructure

# %%
sql_query = "SELECT * FROM geo.datasets WHERE disease IN recommend('disease', 'nephritis', 'match') LIMIT 2000"
result = library_client.query_metadata(query=sql_query, query_api_version="v1")
result
# Out:
# SELECT * FROM geo.datasets WHERE disease IN ('lupus nephritis', 'nephritis, hereditary', 'nephritis, interstitial', 'pyelonephritis', 'glomerulonephritis', 'glomerulonephritis, iga', 'glomerulonephritis, membranoproliferative', 'glomerulonephritis, membranous', 'kidney tubular necrosis, acute, nephritis, interstitial', 'megalocytic interstitial nephritis', 'nephritis') LIMIT 2000
# Query execution succeeded
# Fetched 162 rows
#     publication_name                                 tissue dataset_source  \
# 0           28242240                               [kidney]            GEO
# 1           27942582  [blood plasma, renal proximal tubule]            GEO
# 2           27760209                               [kidney]            GEO
# 3           27760209                                [blood]            GEO
# 4           25840911                               [kidney]            GEO
# ..               ...                                    ...            ...
# 157         28646076                               [kidney]            GEO
# 158             none                                 [None]            GEO
# 159             none                         [renal cortex]            GEO
# 160         30776024                     [renal glomerulus]            GEO
# 161              NaN                               [kidney]            GEO
#
#                                            description             organism  \
# 0    NorUrsodeoxycholic Acid Ameliorates Cholemic N...       [Mus musculus]
# 1    Transcriptional effects of Pentraxin-2 in fibr...       [Mus musculus]
# 2    Kidney gene expression profiles from a lupus n...       [Mus musculus]
# 3    Whole blood gene expression profiles from a lu...       [Mus musculus]
# 4    Macrophage epoxygenase determines a pro-fibrot...  [Rattus norvegicus]
# ..                                                 ...                  ...
# 157  Transcriptomic and proteomic profiling reveal ...       [Homo sapiens]
# 158  Molecular Evidence of Chronic Cellular Rejecti...       [Homo sapiens]
# 159  Global gene expression profiling on renal scar...  [Rattus norvegicus]
# 160   Expression data from podocyte injured glomerulus       [Mus musculus]
# 161  Renal circadian rhythm dysregulation in lupus ...       [Mus musculus]
#
#      year                                            disease  \
# 0    2018             [Nephritis, Interstitial, Cholestasis]
# 1    2018  [Nephritis, Hereditary, Renal Insufficiency, C...
# 2    2018                     [Proteinuria, Lupus Nephritis]
# 3    2018                     [Proteinuria, Lupus Nephritis]
# 4    2018                               [Glomerulonephritis]
# ..    ...                                                ...
# 157  2018  [Segmental glomerulosclerosis, Glomerulonephri...
# 158  2018                               [Glomerulonephritis]
# 159  2018           [Vesico-Ureteral Reflux, Pyelonephritis]
# 160  2018      [Glomerulonephritis, Kidney Failure, Chronic]
# 161   NaN  [Lupus Nephritis, Renal Insufficiency, Protein...
#
#                                              operation    platform  \
# 0    {'is_normalized': 'true', 'batch_corrected_var...  Microarray
# 1    {'is_normalized': 'true', 'batch_corrected_var...  Microarray
# 2    {'is_normalized': 'true', 'batch_corrected_var...  Microarray
# 3    {'is_normalized': 'true', 'batch_corrected_var...  Microarray
# 4    {'is_normalized': 'true', 'batch_corrected_var...      RNASeq
# ..                                                 ...         ...
# 157  {'is_normalized': 'true', 'batch_corrected_var...  Microarray
# 158  {'is_normalized': 'true', 'batch_corrected_var...  Microarray
# 159  {'is_normalized': 'true', 'batch_corrected_var...  Microarray
# 160  {'is_normalized': 'true', 'batch_corrected_var...  Microarray
# 161                                                NaN  Microarray
#
#              dataset_id  ...   kw_timestamp author abstract type file_type  \
# 0     GSE84584_GPL16570  ...  1647620075138    NaN      NaN  NaN       NaN
# 1      GSE85409_GPL6887  ...  1647620156614    NaN      NaN  NaN       NaN
# 2     GSE86423_GPL11180  ...  1647620245266    NaN      NaN  NaN       NaN
# 3     GSE86424_GPL11180  ...  1647620357142    NaN      NaN  NaN       NaN
# 4     GSE65715_GPL18694  ...  1647623785117    NaN      NaN  NaN       NaN
# ..                  ...  ...            ...    ...      ...  ...       ...
# 157   GSE93798_GPL22945  ...  1647620645302    NaN      NaN  NaN       NaN
# 158    GSE93659_GPL6244  ...  1647620748217    NaN      NaN  NaN       NaN
# 159      GSE7087_GPL890  ...  1647619239080    NaN      NaN  NaN       NaN
# 160  GSE112116_GPL16570  ...  1647609380875    NaN      NaN  NaN       NaN
# 161   GSE131892_GPL6885  ...  1647611692269    NaN      NaN  NaN       NaN
#
#     source_process manually_curated processing drug data_matrix_available
# 0              NaN              NaN        NaN  NaN                   NaN
# 1              NaN              NaN        NaN  NaN                   NaN
# 2              NaN              NaN        NaN  NaN                   NaN
# 3              NaN              NaN        NaN  NaN                   NaN
# 4              NaN              NaN        NaN  NaN                   NaN
# ..             ...              ...        ...  ...                   ...
# 157            NaN              NaN        NaN  NaN                   NaN
# 158            NaN              NaN        NaN  NaN                   NaN
# 159            NaN              NaN        NaN  NaN                   NaN
# 160            NaN              NaN        NaN  NaN                   NaN
# 161            NaN              NaN  connector  NaN                   NaN
#
# [162 rows x 46 columns]

# %%
sql_query = "SELECT * FROM geo.datasets WHERE tissue IN recommend('tissue', 'lung', 'related') LIMIT 2000"
result = library_client.query_metadata(query=sql_query, query_api_version="v1")
result
# Out:
# SELECT * FROM geo.datasets WHERE tissue IN ('endothelium', 'olfactory receptor neuron', 'bronchial epithelium', 'respiratory epithelium', 'tracheal epithelium', 'respiratory system', 'lung endothelium', 'bronchiole', 'bud', 'nasal polyp', 'bronchus', 'lung epithelium', 'alveolus', 'pleura', 'pleural cavity', 'lung bud', 'alveolar epithelium', 'bronchial mucosa', 'nasal mucosa', 'lung', 'olfactory epithelium', 'epithelial lining fluid', 'bronchial smooth muscle', 'pleural fluid', 'sputum') LIMIT 2000
# Query execution succeeded
# Fetched 2000 rows
#                                              tissue dataset_source  \
# 0                                      [lung, skin]            GEO
# 1                                            [lung]            GEO
# 2                                            [lung]            GEO
# 3                                            [lung]            GEO
# 4                                            [lung]            GEO
# ...                                             ...            ...
# 1995                                         [lung]            GEO
# 1996                          [polyp, nasal mucosa]            GEO
# 1997                                         [lung]            GEO
# 1998                       [lung, peripheral blood]            GEO
# 1999  [lung, brain, cerebellum, lymph node, breast]            GEO
#
#                                             description        organism  year  \
# 0     Layered ontogeny and in situ perinatal priming...  [Mus musculus]  2019
# 1     TGFβ-induced fibroblast activation requires pe...  [Homo sapiens]  2019
# 2     Unconventional ST2- and CD127-negative lung IL...  [Mus musculus]  2019
# 3     IL-33 blockade impacts mediators of persistenc...  [Mus musculus]  2019
# 4     Impact of transcriptional mutagenesis on p53 t...  [Homo sapiens]  2020
# ...                                                 ...             ...   ...
# 1995  Effect of BET bromodomain inhibitor and/or mTO...  [Homo sapiens]  2020
# 1996  Transcriptome Analysis Identifies Doublesex an...  [Homo sapiens]  2020
# 1997  Severe COVID-19 Is Characterized by an Impaire...  [Homo sapiens]  2021
# 1998  A high OXPHOS CD8 T cell subset is predictive ...  [Homo sapiens]  2020
# 1999  TBCRC 018:  Phase II study of iniparib in comb...  [Homo sapiens]  2013
#
#                                                 disease  \
# 0                     [Hypersensitivity, Helminthiasis]
# 1                                              [Normal]
# 2                               [Asthma, Alternariosis]
# 3                                  [Bronchial Diseases]
# 4                                              [Normal]
# ...                                                 ...
# 1995                        [Small Cell Lung Carcinoma]
# 1996                             [Nasal Polyps, Asthma]
# 1997                                         [COVID-19]
# 1998                         [Lung Neoplasms, Melanoma]
# 1999  [Triple Negative Breast Neoplasms, Brain Neopl...
#
#                                               operation    platform  \
# 0     {'is_normalized': 'true', 'batch_corrected_var...      RNASeq
# 1     {'is_normalized': 'true', 'batch_corrected_var...      RNASeq
# 2     {'is_normalized': 'true', 'batch_corrected_var...      RNASeq
# 3     {'is_normalized': 'true', 'batch_corrected_var...      RNASeq
# 4     {'is_normalized': 'true', 'batch_corrected_var...      RNASeq
# ...                                                 ...         ...
# 1995                                                NaN      RNAseq
# 1996                                                NaN      RNAseq
# 1997                                                NaN      RNAseq
# 1998                                                NaN      RNAseq
# 1999                                                NaN  Microarray
#
#               dataset_id is_public  ... publication_name manually_curated  \
# 0     GSE126924_GPL21103      true  ...              NaN              NaN
# 1     GSE136534_GPL20301      true  ...              NaN              NaN
# 2     GSE136156_GPL17021      true  ...              NaN              NaN
# 3     GSE137324_GPL13112      true  ...         31562870              NaN
# 4     GSE138853_GPL18573      true  ...         32782319              NaN
# ...                  ...       ...  ...              ...              ...
# 1995  GSE155923_GPL20301       NaN  ...              NaN              NaN
# 1996  GSE158277_GPL16791       NaN  ...              NaN              NaN
# 1997  GSE178824_GPL18573       NaN  ...              NaN              NaN
# 1998  GSE152590_GPL22790       NaN  ...              NaN              NaN
# 1999   GSE51280_GPL17590       NaN  ...              NaN              NaN
#
#      file_type source_process geo_summary pubmed_id kw_smiles drug processing  \
# 0          NaN            NaN         NaN       NaN       NaN  NaN        NaN
# 1          NaN            NaN         NaN       NaN       NaN  NaN        NaN
# 2          NaN            NaN         NaN       NaN       NaN  NaN        NaN
# 3          NaN            NaN         NaN       NaN       NaN  NaN        NaN
# 4          NaN            NaN         NaN       NaN       NaN  NaN        NaN
# ...        ...            ...         ...       ...       ...  ...        ...
# 1995       NaN            NaN         NaN       NaN       NaN  NaN  connector
# 1996       NaN            NaN         NaN       NaN       NaN  NaN  connector
# 1997       NaN            NaN         NaN       NaN       NaN  NaN  connector
# 1998       NaN            NaN         NaN       NaN       NaN  NaN  connector
# 1999       NaN            NaN         NaN       NaN       NaN  NaN  connector
#
#      data_matrix_available
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 1995                 False
# 1996                 False
# 1997                 False
# 1998                 False
# 1999                 False
#
# [2000 rows x 46 columns]

# %% [markdown]
# # SQL Queries for V2 storage infrastructure

# %% [markdown]
# ## Previous query on V2 infrastructure
# Before implementation of this feature, users query for a given tissue and disease as shown below.
#
# As per the output, user is able to fetch 929 datasets for the given disease and tissue combination.

# %%
sql_query = """SELECT dataset_id, curated_disease, curated_tissue FROM geo.datasets WHERE 
        CONTAINS(curated_disease,'Breast Neoplasms') AND 
        CONTAINS(curated_tissue,'breast')""" 
result = library_client.query_metadata(query=sql_query, query_api_version="v2")
result
# Out:
# SELECT dataset_id, curated_disease, curated_tissue FROM geo.datasets WHERE
#         CONTAINS(curated_disease,'Breast Neoplasms') AND
#         CONTAINS(curated_tissue,'breast')
# Query execution succeeded (time taken: 12.35 seconds, data scanned: 0.996 MB)
# Fetched 929 rows
#              dataset_id                                    curated_disease  \
# 0      GSE47108_GPL6244                                 [Breast Neoplasms]
# 1        GSE5224_GPL570  [Sialadenitis, Mastitis, Bacterial Infections,...
# 2     GSE62766_GPL13607                                 [Breast Neoplasms]
# 3     GSE69296_GPL10558              [Breast Neoplasms, Ovarian Neoplasms]
# 4     GSE71283_GPL13497                 [Breast Neoplasms, Fanconi Anemia]
# ..                  ...                                                ...
# 924    GSE28556_GPL6885  [Neuroblastoma, Melanoma, Breast Neoplasms, Gl...
# 925   GSE36565_GPL10558                      [Neoplasms, Breast Neoplasms]
# 926       GSE6324_GPL96  [Neoplasms, Blister, Unilateral Breast Neoplas...
# 927    GSE19536_GPL6480                                 [Breast Neoplasms]
# 928  GSE139688_GPL18573          [Breast Neoplasms, Lymphoma, Non-Hodgkin]
#
#                          curated_tissue
# 0                              [breast]
# 1    [mammary gland, forebrain, breast]
# 2                              [breast]
# 3                              [breast]
# 4                              [breast]
# ..                                  ...
# 924      [breast, muscle, liver, heart]
# 925                            [breast]
# 926          [bone, osteoclast, breast]
# 927                [lymph node, breast]
# 928                            [breast]
#
# [929 rows x 3 columns]

# %% [markdown]
# ## New queries after implementation of ontology recommendations
# Now the users can query as shown below.
#
# As per the output, user is able to fetch only 1441 datasets for the given disease and tissue combination.

# %%
sql_query = """SELECT dataset_id, curated_disease, curated_tissue FROM geo.datasets WHERE 
        CONTAINS(curated_disease, recommend('curated_disease', 'breast neoplasms', 'related')) AND 
        CONTAINS(curated_tissue, recommend('curated_tissue', 'breast', 'related'))""" 
result = library_client.query_metadata(query=sql_query, query_api_version="v2")
result
# Out:
# SELECT dataset_id, curated_disease, curated_tissue FROM geo.datasets WHERE
#         (CONTAINS(curated_disease, 'Breast Neoplasms, Male') OR CONTAINS(curated_disease, 'Unilateral Breast Neoplasms') OR CONTAINS(curated_disease, 'Breast Neoplasms') OR CONTAINS(curated_disease, ' Breast Neoplasms') OR CONTAINS(curated_disease, 'Carcinoma, Ductal, Breast') OR CONTAINS(curated_disease, 'Inflammatory Breast Neoplasms') OR CONTAINS(curated_disease, 'Breast Neoplasms ') OR CONTAINS(curated_disease, 'Triple Negative Breast Neoplasms')) AND
#         (CONTAINS(curated_tissue, 'milk fat') OR CONTAINS(curated_tissue, 'epithelium') OR CONTAINS(curated_tissue, 'mammary gland') OR CONTAINS(curated_tissue, 'breast epithelium') OR CONTAINS(curated_tissue, 'breast') OR CONTAINS(curated_tissue, 'nipple') OR CONTAINS(curated_tissue, 'milk') OR CONTAINS(curated_tissue, 'mammary duct') OR CONTAINS(curated_tissue, 'thorax') OR CONTAINS(curated_tissue, 'colostrum') OR CONTAINS(curated_tissue, 'mammary epithelium'))
# Query execution succeeded (time taken: 14.15 seconds, data scanned: 1.004 MB)
# Fetched 1441 rows
#               dataset_id                                    curated_disease  \
# 0     GSE122630_GPL17303                                 [Breast Neoplasms]
# 1      GSE76487_GPL11154  [Breast Neoplasms, Neoplasm Metastasis, Myoton...
# 2          GSE6596_GPL96                                 [Breast Neoplasms]
# 3       GSE72644_GPL6480                                 [Breast Neoplasms]
# 4      GSE74539_GPL10558                                 [Breast Neoplasms]
# ...                  ...                                                ...
# 1436   GSE89206_GPL17303                                 [Breast Neoplasms]
# 1437    GSE63025_GPL6246                                 [Breast Neoplasms]
# 1438       GSE6324_GPL96  [Neoplasms, Blister, Unilateral Breast Neoplas...
# 1439    GSE76360_GPL6947  [Triple Negative Breast Neoplasms, Neoplasm In...
# 1440    GSE19536_GPL6480                                 [Breast Neoplasms]
#
#                   curated_tissue
# 0                       [breast]
# 1                       [breast]
# 2                [mammary gland]
# 3     [epithelium, mammary duct]
# 4                       [breast]
# ...                          ...
# 1436             [mammary gland]
# 1437             [mammary gland]
# 1438  [bone, osteoclast, breast]
# 1439              [breast, node]
# 1440        [lymph node, breast]
#
# [1441 rows x 3 columns]

# %% [markdown]
# ## Other query examples on V2 infrastructure

# %%
sql_query = """SELECT * FROM geo.datasets WHERE 
                CONTAINS(curated_disease, recommend('curated_disease', 'hepatitis', 'match'))"""
result = library_client.query_metadata(query=sql_query, query_api_version="v2")
result
# Out:
# SELECT * FROM geo.datasets WHERE
#                 (CONTAINS(curated_disease, 'Hepatitis B, Chronic') OR CONTAINS(curated_disease, 'Hepatitis C, Chronic') OR CONTAINS(curated_disease, 'Hepatitis B') OR CONTAINS(curated_disease, 'Hepatitis A') OR CONTAINS(curated_disease, 'Hepatitis C') OR CONTAINS(curated_disease, 'Hepatitis D') OR CONTAINS(curated_disease, 'Hepatitis E') OR CONTAINS(curated_disease, 'Hepatitis, Autoimmune') OR CONTAINS(curated_disease, 'Hepatitis, Alcoholic') OR CONTAINS(curated_disease, 'Hepatitis, Chronic') OR CONTAINS(curated_disease, 'Hepatitis, Viral, Human') OR CONTAINS(curated_disease, 'Hepatitis') OR CONTAINS(curated_disease, 'Hepatitis B ') OR CONTAINS(curated_disease, 'Hepatitis C ') OR CONTAINS(curated_disease, 'Schistosomiasis Japonica, Hepatitis B'))
# Query execution succeeded (time taken: 13.39 seconds, data scanned: 25.490 MB)
# Fetched 345 rows
#     curated_organism                                            src_uri  \
# 0     [Homo sapiens]  polly:data://GEO_data_lake/data/Microarray/GSE...
# 1     [Homo sapiens]  polly:data://GEO_data_lake/data/Microarray/GSE...
# 2     [Homo sapiens]  polly:data://GEO_data_lake/data/Microarray/GSE...
# 3     [Homo sapiens]  polly:data://GEO_data_lake/data/RNASeq/GSE1042...
# 4     [Homo sapiens]  polly:data://GEO_data_lake/data/RNASeq/GSE1415...
# ..               ...                                                ...
# 340   [Homo sapiens]  polly:data://GEO_data_lake/data/RNASeq/GSE1029...
# 341   [Homo sapiens]  polly:data://GEO_data_lake/data/RNASeq/GSE1050...
# 342   [Homo sapiens]  polly:data://GEO_data_lake/data/Microarray/GSE...
# 343   [Homo sapiens]  polly:data://GEO_data_lake/data/Microarray/GSE...
# 344   [Homo sapiens]  polly:data://GEO_data_lake/data/Microarray/GSE...
#
#      total_num_samples    year  \
# 0                  6.0  2018.0
# 1                  NaN  2007.0
# 2                  6.0  2018.0
# 3                 10.0  2019.0
# 4                 91.0  2020.0
# ..                 ...     ...
# 340                4.0  2018.0
# 341               12.0  2018.0
# 342                6.0  2018.0
# 343               48.0  2018.0
# 344                4.0  2018.0
#
#                                            description     curated_cell_line  \
# 0    Gene expression analysis of Neoechinulin B (Ne...           [Huh-7.5.1]
# 1    Expression data of HCV-associated advance dise...                [None]
# 2    Role of caveolin-1 in hepatocellular carcinoma...  [Hep-G2, HLE, Huh-7]
# 3    miRNA sequencing of serum exosomes from hepato...                [None]
# 4    Large-scale screening of circulating microRNAs...                [None]
# ..                                                 ...                   ...
# 340  The hepatitis C viral protein NS5A stabilizes ...                [None]
# 341  Gene expression analysis of human liver progen...                [None]
# 342  Global re-wiring of p53 transcription regulati...              [Hep-G2]
# 343  Targeting innate immunity for antiviral therap...               [THP-1]
# 344  miRNA Signatures indicate Acute Liver Failure ...                [None]
#
#              data_table_name  data_table_version    platform     timestamp_  \
# 0     geo__gse63026_gpl10558                 0.0  Microarray  1650501838066
# 1                        NaN                 NaN  Microarray  1650502936804
# 2     geo__gse99131_gpl16686                 0.0  Microarray  1650504311882
# 3    geo__gse104251_gpl11154                 0.0      RNASeq  1650504180673
# 4    geo__gse141522_gpl16791                 0.0      RNASeq  1650504818401
# ..                       ...                 ...         ...            ...
# 340  geo__gse102910_gpl11154                 0.0      RNASeq  1650504107282
# 341  geo__gse105019_gpl16791                 0.0      RNASeq  1650504182004
# 342   geo__gse64875_gpl13607                 0.0  Microarray  1650501995675
# 343   geo__gse74047_gpl16699                 0.0  Microarray  1650502716795
# 344   geo__gse79197_gpl10558                 0.0  Microarray  1650503067061
#
#      ...                                           abstract version  \
# 0    ...                                                NaN       0
# 1    ...                                                NaN       0
# 2    ...                                                NaN       0
# 3    ...  Exosomal microRNAs have recently been studied ...       0
# 4    ...  Human immunodeficiency virus type 1 (HIV-1)-in...       0
# ..   ...                                                ...     ...
# 340  ...                                                NaN       0
# 341  ...                                                NaN       0
# 342  ...                                                NaN       0
# 343  ...                                                NaN       0
# 344  ...                                                NaN       0
#
#     curated_strain                     bucket  curated_tissue dataset_source  \
# 0           [None]  discover-prod-datalake-v1          [None]            GEO
# 1           [None]  discover-prod-datalake-v1         [liver]            GEO
# 2           [None]  discover-prod-datalake-v1         [liver]            GEO
# 3           [None]  discover-prod-datalake-v1         [liver]            GEO
# 4           [None]  discover-prod-datalake-v1  [blood plasma]            GEO
# ..             ...                        ...             ...            ...
# 340         [None]  discover-prod-datalake-v1          [None]            GEO
# 341         [None]  discover-prod-datalake-v1          [None]            GEO
# 342         [None]  discover-prod-datalake-v1          [None]            GEO
# 343         [None]  discover-prod-datalake-v1          [None]            GEO
# 344         [None]  discover-prod-datalake-v1         [liver]            GEO
#
#            data_type                                     overall_design  \
# 0    Transcriptomics  Total RNA obtained from NeoB-treated and un-tr...
# 1    Transcriptomics  Liver biopsy samples were collected from patie...
# 2    Transcriptomics  The aim of this study is to identify an import...
# 3    Transcriptomics  Deep sequencing was performed to screen differ...
# 4    Transcriptomics  In total 97 plasma derived small RNA samples w...
# ..               ...                                                ...
# 340  Transcriptomics  Calculate mRNA decay rate by examining RNA-seq...
# 341  Transcriptomics  Human liver progenitor-like cells were derived...
# 342  Transcriptomics  HepG2 cells were transduced with recombinant H...
# 343  Transcriptomics  THP-1 cells were differentiated in 40nM PMA fo...
# 344  Transcriptomics  Illumina based genome wide expression profilin...
#
#     is_current     region
# 0         True  us-west-2
# 1         True  us-west-2
# 2         True  us-west-2
# 3         True  us-west-2
# 4         True  us-west-2
# ..         ...        ...
# 340       True  us-west-2
# 341       True  us-west-2
# 342       True  us-west-2
# 343       True  us-west-2
# 344       True  us-west-2
#
# [345 rows x 34 columns]

# %%
sql_query = """SELECT * FROM geo.datasets WHERE 
            CONTAINS(curated_tissue, recommend('curated_tissue', 'liver', 'related'))"""
result = library_client.query_metadata(query=sql_query, query_api_version="v2")
result
# Out:
# SELECT * FROM geo.datasets WHERE
#             (CONTAINS(curated_tissue, 'liver bud') OR CONTAINS(curated_tissue, 'bud') OR CONTAINS(curated_tissue, 'hepatocyte') OR CONTAINS(curated_tissue, 'bile') OR CONTAINS(curated_tissue, 'liver') OR CONTAINS(curated_tissue, 'bile duct'))
# Query execution succeeded (time taken: 14.74 seconds, data scanned: 31.864 MB)
# Fetched 4213 rows
#      curated_organism                                            src_uri  \
# 0      [Mus musculus]  polly:data://GEO_data_lake/data/Microarray/GSE...
# 1      [Mus musculus]  polly:data://GEO_data_lake/data/Microarray/GSE...
# 2      [Mus musculus]  polly:data://GEO_data_lake/data/Microarray/GSE...
# 3      [Mus musculus]  polly:data://GEO_data_lake/data/Microarray/GSE...
# 4      [Mus musculus]  polly:data://GEO_data_lake/data/Microarray/GSE...
# ...               ...                                                ...
# 4208   [Mus musculus]  polly:data://GEO_data_lake/data/RNASeq/GSE7048...
# 4209   [Homo sapiens]  polly:data://GEO_data_lake/data/RNASeq/GSE7126...
# 4210   [Mus musculus]  polly:data://GEO_data_lake/data/RNASeq/GSE8929...
# 4211   [Mus musculus]  polly:data://GEO_data_lake/data/RNASeq/GSE9858...
# 4212   [Mus musculus]  polly:data://GEO_data_lake/data/RNASeq/GSE9944...
#
#       total_num_samples    year  \
# 0                  12.0  2018.0
# 1                  15.0  2015.0
# 2                  28.0  2018.0
# 3                  21.0  2016.0
# 4                  12.0  2015.0
# ...                 ...     ...
# 4208               84.0  2018.0
# 4209                4.0  2019.0
# 4210               14.0  2018.0
# 4211                5.0  2019.0
# 4212               39.0  2018.0
#
#                                             description curated_cell_line  \
# 0     Specific Genomic and Transcriptomic Aberration...            [None]
# 1     Transcriptional regulation of hepatic target g...            [None]
# 2     Characterization of RA839, a non-covalent smal...            [None]
# 3     JNK1 Ablation in Mice Confers Long-term Metabo...            [None]
# 4     Fucoidan alleviates high-fat diet-induced dysl...            [None]
# ...                                                 ...               ...
# 4208  Noncanonical Genomic Imprinting Effects In Off...            [None]
# 4209  Genome-wide maps of PBX3-binding sites and Qua...       [SMMC-7721]
# 4210  Role of liquid sugar in regulating the hepatic...            [None]
# 4211  Gene expression profiling of continuous growth...            [None]
# 4212  Reduced circulating insulin enhances insulin s...            [None]
#
#              data_table_name  data_table_version    platform     timestamp_  \
# 0      geo__gse61422_gpl6246                 0.0  Microarray  1650502117178
# 1      geo__gse68867_gpl6887                 0.0  Microarray  1650502269876
# 2      geo__gse71695_gpl1261                 0.0  Microarray  1650502556292
# 3      geo__gse73759_gpl7202                 0.0  Microarray  1650502694124
# 4     geo__gse76374_gpl15043                 0.0  Microarray  1650502175008
# ...                      ...                 ...         ...            ...
# 4208  geo__gse70484_gpl13112                 0.0      RNASeq  1650506703326
# 4209  geo__gse71262_gpl11154                 0.0      RNASeq  1650506597326
# 4210  geo__gse89296_gpl17021                 0.0      RNASeq  1650507324191
# 4211  geo__gse98584_gpl13112                 0.0      RNASeq  1650507831483
# 4212  geo__gse99440_gpl13112                 0.0      RNASeq  1650507060372
#
#       ...                                           abstract version  \
# 0     ...                                                NaN       0
# 1     ...                                                NaN       0
# 2     ...                                                NaN       0
# 3     ...                                                NaN       0
# 4     ...                                                NaN       0
# ...   ...                                                ...     ...
# 4208  ...                                                NaN       0
# 4209  ...  This SuperSeries is composed of the SubSeries ...       0
# 4210  ...                                                NaN       0
# 4211  ...  PolyA-selected RNA isolated from livers of adu...       0
# 4212  ...                                                NaN       0
#
#      curated_strain                     bucket  \
# 0           [FVB/N]  discover-prod-datalake-v1
# 1         [C57BL/6]  discover-prod-datalake-v1
# 2            [None]  discover-prod-datalake-v1
# 3            [None]  discover-prod-datalake-v1
# 4               [L]  discover-prod-datalake-v1
# ...             ...                        ...
# 4208     [C57BL/6J]  discover-prod-datalake-v1
# 4209         [None]  discover-prod-datalake-v1
# 4210     [C57BL/6N]  discover-prod-datalake-v1
# 4211         [None]  discover-prod-datalake-v1
# 4212         [None]  discover-prod-datalake-v1
#
#                                          curated_tissue dataset_source  \
# 0                                               [liver]            GEO
# 1                                               [liver]            GEO
# 2                                  [bone marrow, liver]            GEO
# 3                         [liver, adipose tissue, skin]            GEO
# 4                  [white adipose tissue, liver, aorta]            GEO
# ...                                                 ...            ...
# 4208  [dorsal raphe nucleus, arcuate nucleus, liver,...            GEO
# 4209                                            [liver]            GEO
# 4210                            [adipose tissue, liver]            GEO
# 4211                                            [liver]            GEO
# 4212                          [hindlimb, muscle, liver]            GEO
#
#             data_type                                     overall_design  \
# 0     Transcriptomics  To explore the mechanisms of the accelerated H...
# 1     Transcriptomics  Mice received daily intraperitoneal injection ...
# 2     Transcriptomics  Gene expression profile of bone marrow derived...
# 3     Transcriptomics  RNA was collected from liver, skin and epididy...
# 4     Transcriptomics  Fucoidan were ingested by fed a high-fat diet ...
# ...               ...                                                ...
# 4208  Transcriptomics  Examination of allele-specific gene expression...
# 4209  Transcriptomics                         Refer to individual Series
# 4210  Transcriptomics  Hepatic mRNA profiles of chow, HFWD, and HFWD+...
# 4211  Transcriptomics  Liver RNA was isolated from 8 week old male mi...
# 4212  Transcriptomics  RNAsequencing expression profiles of livers an...
#
#      is_current     region
# 0          True  us-west-2
# 1          True  us-west-2
# 2          True  us-west-2
# 3          True  us-west-2
# 4          True  us-west-2
# ...         ...        ...
# 4208       True  us-west-2
# 4209       True  us-west-2
# 4210       True  us-west-2
# 4211       True  us-west-2
# 4212       True  us-west-2
#
# [4213 rows x 34 columns]

# %%
sql_query = """SELECT dataset_id, curated_disease, curated_tissue FROM geo.datasets 
WHERE (CONTAINS(curated_disease, recommend('curated_disease', 'breast neoplasms', 'related')) OR
CONTAINS(curated_disease, recommend('curated_disease', 'pancreatic neoplasms', 'related')))AND 
(CONTAINS(curated_tissue, recommend('curated_tissue', 'breast', 'related')) OR 
CONTAINS(curated_tissue, recommend('curated_tissue', 'pancreas', 'related')))"""
result = library_client.query_metadata(query=sql_query, query_api_version="v2")
result
# Out:
# SELECT dataset_id, curated_disease, curated_tissue FROM geo.datasets
# WHERE ((CONTAINS(curated_disease, 'Breast Neoplasms, Male') OR CONTAINS(curated_disease, 'Unilateral Breast Neoplasms') OR CONTAINS(curated_disease, 'Breast Neoplasms') OR CONTAINS(curated_disease, ' Breast Neoplasms') OR CONTAINS(curated_disease, 'Carcinoma, Ductal, Breast') OR CONTAINS(curated_disease, 'Inflammatory Breast Neoplasms') OR CONTAINS(curated_disease, 'Breast Neoplasms ') OR CONTAINS(curated_disease, 'Triple Negative Breast Neoplasms')) OR
# (CONTAINS(curated_disease, 'Vipoma') OR CONTAINS(curated_disease, 'Pancreatic Neoplasms ') OR CONTAINS(curated_disease, 'Adenoma, Islet Cell') OR CONTAINS(curated_disease, 'Carcinoma, Pancreatic Ductal') OR CONTAINS(curated_disease, 'Pancreatic Neoplasms') OR CONTAINS(curated_disease, 'Insulinoma')))AND
# ((CONTAINS(curated_tissue, 'milk fat') OR CONTAINS(curated_tissue, 'epithelium') OR CONTAINS(curated_tissue, 'mammary gland') OR CONTAINS(curated_tissue, 'breast epithelium') OR CONTAINS(curated_tissue, 'breast') OR CONTAINS(curated_tissue, 'nipple') OR CONTAINS(curated_tissue, 'milk') OR CONTAINS(curated_tissue, 'mammary duct') OR CONTAINS(curated_tissue, 'thorax') OR CONTAINS(curated_tissue, 'colostrum') OR CONTAINS(curated_tissue, 'mammary epithelium')) OR
# (CONTAINS(curated_tissue, 'pancreas') OR CONTAINS(curated_tissue, 'pancreatic islet') OR CONTAINS(curated_tissue, 'exocrine pancreas') OR CONTAINS(curated_tissue, 'endocrine pancreas') OR CONTAINS(curated_tissue, 'pancreatic duct')))
# Query execution succeeded (time taken: 12.73 seconds, data scanned: 1.005 MB)
# Fetched 1591 rows
#              dataset_id                                    curated_disease  \
# 0      GSE23720_GPL9128  [Colonic Neoplasms, Prostatic Neoplasms, Esoph...
# 1     GSE56614_GPL16791  [Leukemia, Myeloid, Acute, Breast Neoplasms, C...
# 2     GSE61375_GPL11154                                 [Breast Neoplasms]
# 3     GSE75473_GPL15520  [Muscular Dystrophies, Colorectal Neoplasms, O...
# 4     GSE55947_GPL13915                      [Neoplasms, Breast Neoplasms]
# ...                 ...                                                ...
# 1586   GSE26539_GPL7504                                 [Breast Neoplasms]
# 1587  GSE28472_GPL13224  [Melanoma, Hematologic Neoplasms, Breast Neopl...
# 1588   GSE34651_GPL2877         [Pancreatic Neoplasms, Pancreatic adenoma]
# 1589      GSE4025_GPL96                                 [Breast Neoplasms]
# 1590    GSE44408_GPL571  [Triple Negative Breast Neoplasms, Carcinoma, ...
#
#                                          curated_tissue
# 0                                              [breast]
# 1                                              [breast]
# 2                                              [breast]
# 3                           [skeletal muscle, pancreas]
# 4                                              [breast]
# ...                                                 ...
# 1586                                           [breast]
# 1587  [breast, kidney, blood, colon, uterine cervix,...
# 1588                                         [pancreas]
# 1589                                           [breast]
# 1590                        [lymph node, breast, lymph]
#
# [1591 rows x 3 columns]
