# %% [markdown]
# # Prototype notebook : Querying data across all Omix Atlas
# _For internal use only_
#
# ### Instructions:
#
# 1. Please run all code cells one by one.
# 2. User is required to enter an SQL query to search for the required datasets.

# %% [markdown]
# ## Install polly-python

# %%
# !pip3 install polly-python --user

# %%
from polly.omixatlas import OmixAtlas
import pandas as pd
import sys
import time
import re
import traceback

# %% [markdown]
# ## Authentication with Polly

# %%
repo_client = OmixAtlas(os.environ['POLLY_REFRESH_TOKEN'])

# %% [markdown]
# ## Get all OmixAtlas

# %%
all_omix_atlas = pd.DataFrame.from_dict(repo_client.get_all_omixatlas()['data'])

# %%
all_omix_atlas
# Out:
#           repo_name        repo_id  \
# 0               gdc  1623221686703
# 1               geo              9
# 2  enterprise_atlas  1638441282192
# 3   liveromix_atlas  1615965444377
# 4        cbioportal  1623986995264
# 5               pcd  1622113130397
# 6             lincs             32
# 7      metabolomics             23
# 8      sc_data_lake             17
#
#                                              indexes  \
# 0  {'gct_metadata': 'gdc_gct_metadata', 'h5ad_met...
# 1  {'gct_metadata': 'geo_gct_metadata', 'h5ad_met...
# 2  {'gct_metadata': 'enterprise_atlas_gct_metadat...
# 3  {'gct_metadata': 'liveromix_atlas_gct_metadata...
# 4  {'gct_metadata': 'cbioportal_gct_metadata', 'h...
# 5  {'gct_metadata': 'pcd_gct_metadata', 'h5ad_met...
# 6  {'gct_metadata': 'lincs_gct_metadata', 'h5ad_m...
# 7  {'gct_metadata': 'metabolomics_gct_metadata', ...
# 8  {'gct_metadata': 'sc_data_lake_gct_metadata', ...
#
#                                             diseases  \
# 0  [leukemia, myeloid, acute, precursor t-cell ly...
# 1  [normal, neoplasms, breast neoplasms, obesity,...
# 2  [breast neoplasms, endometrial neoplasms, endo...
# 3  [normal, carcinoma, hepatocellular, obesity, n...
# 4  [prostatic neoplasms, carcinoma, ductal, breas...
# 5  [none, adenocarcinoma, carcinoma, squamous cel...
# 6  [prostatic neoplasms, normal, colorectal neopl...
# 7  [normal, neoplasms, diabetes mellitus, obesity...
# 8  [normal, neoplasms, breast neoplasms, melanoma...
#
#                                            organisms  \
# 0                                     [homo sapiens]
# 1  [homo sapiens, mus musculus, rattus norvegicus...
# 2                       [homo sapiens, mus musculus]
# 3  [homo sapiens, mus musculus, rattus norvegicus...
# 4                                     [homo sapiens]
# 5                                     [homo sapiens]
# 6                                     [homo sapiens]
# 7  [homo sapiens, mus musculus, rattus norvegicus...
# 8  [mus musculus, homo sapiens, macaca fascicular...
#
#                                              sources  \
# 0                                              [gdc]
# 1                                              [geo]
# 2                                 [geo, proprietary]
# 3  [geo, lincs, tcga, metabolomics workbench, met...
# 4                                       [cbioportal]
# 5                                       [pharmacodb]
# 6                                  [geo, geo, lincs]
# 7  [metabolomics workbench, metabolights, publica...
# 8  [geo, humancellatlas, gene expression omnibus ...
#
#                                            datatypes  dataset_count  \
# 0  [mirna expression, transcriptomics, copy numbe...           9869
# 1                                  [transcriptomics]          10000
# 2    [transcriptomics, single cell, mutation, mirna]            176
# 3  [transcriptomics, mutation, metabolomics, sing...           6761
# 4  [mutation, copy number variation, fusion, tran...          10000
# 5                                    [drug response]          10000
# 6                                  [transcriptomics]          10000
# 7            [metabolomics, lipidomics, single cell]           1777
# 8                                      [single cell]           2915
#
#    disease_count  tissue_count  organism_count  cell_line_count  \
# 0             75            41               1                1
# 1           3028           980              68             4300
# 2             35            25               2               96
# 3            752            60              22              347
# 4            330           262               1                1
# 5            133            34               1             1399
# 6             34            21               1               84
# 7            214           134             184               24
# 8            520           414               5               69
#
#    cell_type_count  drug_count  data_type_count  data_source_count  \
# 0                1           1                3                  1
# 1              780        1379                1                  1
# 2               40          21                4                  2
# 3              310        4704               12                 10
# 4                1           1                5                  1
# 5                1         749                1                  1
# 6                1       20347                1                  2
# 7               23          67                3                  4
# 8              406          80                1                  6
#
#    sample_count  normal_sample_count
# 0          5353                    0
# 1       1279490               839985
# 2          8952                 3927
# 3        143535               110202
# 4         58994                    0
# 5        653500                    0
# 6       1371945                    0
# 7         90677                    0
# 8        207888                    0

# %% [markdown]
# ## Get all dataset level indexes

# %%
all_indexes = list(all_omix_atlas['indexes'])
dataset_index = [ ind['files'] for ind in all_indexes ]

# %% [markdown]
# ## Searching across all OA

# %%
def query_split(query):
    
    """
    Returns N SQL queries equal to the number of input indexes
    
    Extended description of function.
    
    Parameters:
    query (str): input SQL query to search across any given omixatlases
    
    Returns:
    q_list (list): list of SQL queries where each query queries on a single index only.
    
    """
    
    index_search = re.search("from(.*)where", query, re.IGNORECASE)
    index_list = index_search.group(1).split(',')
    index_list = [index.strip() for index in index_list]
    
    const_string1 = query.split(index_list[0]) #Extract constant SQL query
    const_string2 = query.split(index_list[-1]) #Extract constant SQL query
    
    q_list = []
    
    for index in index_list:
        q = f"{const_string1[0]}{index}{const_string2[-1]}"
        q_list.append(q)
    
    return q_list
    

def for_loop(query_list):
    
    """
    Returns a table containing dataset level metadata for all datasets based on the input SQL query
    
    Extended description of function.
    
    Parameters:
    query_list (list): list of input SQL queries where each query is used to search across a single omixatlas
    
    Returns:
    df_result (dataframe): DataFrame containing dataset level metadata of the resulting datasets.
    
    """

    df_list = []
    
    for query in query_list:
        all_df = repo_client.query_metadata(query)
        if all_df is not None:
            df_list.append(all_df)
    
    df_result = pd.concat(df_list) #Merge all results into a single table
    
    return df_result

def multi_index(query):

    all_df = repo_client.query_metadata(query)
    return all_df

# %% [markdown]
# ## Input SQL query
#
# #### List of available dataset indexes
#
# 1. gdc_files
# 2. geo_files
# 3. enterprise_atlas_files
# 4. liveromix_atlas_files
# 5. cbioportal_files
# 6. pcd_files
# 7. lincs_files
# 8. metabolomics_files
# 9. sc_data_lake_files

# %%
if __name__ == "__main__":
    
    sql = "SELECT * from pcd_files, geo_files WHERE disease = 'Carcinoma, Hepatocellular' LIMIT 2000"
    
    start_time = time.time()
    try:
        result_df = multi_index(sql)
    except Exception as e:
        print('Caught this Exception: ' + repr(e))
        query_list = query_split(sql)
        result_df = for_loop(query_list)
    
    print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Caught this error: VerificationException()
# {'query_used': "SELECT * from pcd_files WHERE disease = 'Carcinoma, Hepatocellular' LIMIT 2000", 'message': 'Showing 1 - 603 of 603 matching results'}
# {'query_used': "SELECT * from geo_files WHERE disease = 'Carcinoma, Hepatocellular' LIMIT 2000", 'message': 'Showing 1 - 942 of 942 matching results'}
# --- 45.4629647731781 seconds ---

# %%
result_df
# Out:
#     dataset_source                                         dataset_id  \
# 0       PharmacoDB  17-AAG_haematopoietic_and_lymphoid_tissue_GDSC...
# 1       PharmacoDB  16-beta-bromoandrosterone_haematopoietic_and_l...
# 2       PharmacoDB  5-FU_haematopoietic_and_lymphoid_tissue_CTRPv2...
# 3       PharmacoDB  ABT-199_haematopoietic_and_lymphoid_tissue_CTR...
# 4       PharmacoDB  AP-24534_haematopoietic_and_lymphoid_tissue_GD...
# ..             ...                                                ...
# 937            GEO                                  GSE82177_GPL11154
# 938            GEO                                  GSE84186_GPL11154
# 939            GEO                                  GSE87240_GPL11154
# 940            GEO                                  GSE85427_GPL13112
# 941            GEO                                  GSE97412_GPL18573
#
#                                            description  \
# 0    dose response data for 17-AAG drug and cell li...
# 1    dose response data for 16-beta-bromoandrostero...
# 2    dose response data for 5-FU drug and cell line...
# 3    dose response data for ABT-199 drug and cell l...
# 4    dose response data for AP-24534 drug and cell ...
# ..                                                 ...
# 937  Human liver RNA-seq data corresponding to unin...
# 938  Single-nucleotide-resolution mapping of HBV pr...
# 939  S-adenosyl-methionine treatment selectively bl...
# 940  Insulin-like Growth Factor Binding Protein-7 (...
# 941  Expression analysis of INO80 complex in HepG2 ...
#
#                                           kw_cell_line        organism  \
# 0    [BC-1, Jurkat, GR-ST, AMO1, Ku812, K-562, WSU-...    Homo sapiens
# 1    [Jurkat, MHH-CALL-4, JK-1, HPB-ALL, Ku812, KMS...    Homo sapiens
# 2    [Jurkat, MHH-CALL-4, JK-1, HPB-ALL, Ku812, KMS...    Homo sapiens
# 3    [MHH-CALL-4, JK-1, HPB-ALL, AMO1, ME1, RPMI-82...    Homo sapiens
# 4    [SCC-3, BC-1, GR-ST, AMO1, Ku812, K-562, WSU-N...    Homo sapiens
# ..                                                 ...             ...
# 937                                             [None]  [Homo sapiens]
# 938                           [Hep-G2/2.2.15, HepAD38]  [Homo sapiens]
# 939                                             [None]  [Homo sapiens]
# 940                                             [None]  [Mus musculus]
# 941                                           [Hep-G2]  [Homo sapiens]
#
#             year                                          operation kw_source  \
# 0           2018  {'is_normalized': 'false', 'normalized_type': ...  GDSC1000
# 1           2018  {'is_normalized': 'false', 'normalized_type': ...    CTRPv2
# 2           2018  {'is_normalized': 'false', 'normalized_type': ...    CTRPv2
# 3           2018  {'is_normalized': 'false', 'normalized_type': ...    CTRPv2
# 4           2018  {'is_normalized': 'false', 'normalized_type': ...  GDSC1000
# ..           ...                                                ...       ...
# 937         2018  {'is_normalized': 'true', 'batch_corrected_var...       NaN
# 938         2018  {'is_normalized': 'true', 'batch_corrected_var...       NaN
# 939         2018  {'is_normalized': 'true', 'batch_corrected_var...       NaN
# 940  Oct 01 2019  {'is_normalized': 'true', 'batch_corrected_var...       NaN
# 941  Apr 01 2020  {'is_normalized': 'true', 'batch_corrected_var...       NaN
#
#     is_public data_repository  ...  kw_strain file_type source_process  \
# 0        true      PharmacoDB  ...        NaN       NaN            NaN
# 1        true      PharmacoDB  ...        NaN       NaN            NaN
# 2        true      PharmacoDB  ...        NaN       NaN            NaN
# 3        true      PharmacoDB  ...        NaN       NaN            NaN
# 4        true      PharmacoDB  ...        NaN       NaN            NaN
# ..        ...             ...  ...        ...       ...            ...
# 937      true             geo  ...     [None]       NaN            NaN
# 938      true             geo  ...     [None]       NaN            NaN
# 939      true             geo  ...     [None]       NaN            NaN
# 940      true             geo  ...  [C57BL/6]       NaN            NaN
# 941      true             geo  ...     [None]       NaN            NaN
#
#     processing drug        author  \
# 0          NaN  NaN           NaN
# 1          NaN  NaN           NaN
# 2          NaN  NaN           NaN
# 3          NaN  NaN           NaN
# 4          NaN  NaN           NaN
# ..         ...  ...           ...
# 937        NaN  NaN           NaN
# 938        NaN  NaN           NaN
# 939        NaN  NaN           NaN
# 940        NaN  NaN  Yidong,,Chen
# 941        NaN  NaN   Jesse,,Raab
#
#                                               abstract  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 937                                                NaN
# 938                                                NaN
# 939                                                NaN
# 940  Insulin like growth factor binding protein-7 (...
# 941  We carried out two sets of experiments to unde...
#
#                                         overall_design  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 937                                                NaN
# 938                                                NaN
# 939                                                NaN
# 940  Three replicates of RNAs derived from WT and I...
# 941  HepG2 cells were treated with siRNA against IN...
#
#                                                summary  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 937                                                NaN
# 938                                                NaN
# 939                                                NaN
# 940  Insulin like growth factor binding protein-7 (...
# 941  We carried out two sets of experiments to unde...
#
#                                                   type
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 937                                                NaN
# 938                                                NaN
# 939                                                NaN
# 940  Expression profiling by high throughput sequen...
# 941  Expression profiling by high throughput sequen...
#
# [1545 rows x 42 columns]
