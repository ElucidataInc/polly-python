# %%
# %pip install polly-python
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 kB 3.1 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.2/150.2 kB 7.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tabulate
#     Found existing installation: tabulate 0.8.10
#     Uninstalling tabulate-0.8.10:
#       Successfully uninstalled tabulate-0.8.10
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 3.2.0
#     Uninstalling charset-normalizer-3.2.0:
#       Successfully uninstalled charset-normalizer-3.2.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: polly-python
#     Found existing installation: polly-python 1.0.0
#     Uninstalling polly-python-1.0.0:
#       Successfully uninstalled polly-python-1.0.0
# ...

# %%
# import

import os
import json
from polly.auth import Polly
from polly.workspaces import Workspaces
import pandas as pd

# %%
# authentication 

AUTH_KEY = "auth key"
Polly.auth(AUTH_KEY, env="polly")

# %%
# connect to workspace

workspaces = Workspaces()

# %%
# get all workspaces

workspaces.fetch_my_workspaces()
# Out:
#      Workspace_id                   Workspace_name    status description  \
# 0           16562              test_function_anshu    active        None
# 1           16563                     test_srishti    active
# 2           16556                        new WS 21    active
# 3           16531                _PRD-870_Restored    active
# 4           15487                  Test 2_Restored    active
# ..            ...                              ...       ...         ...
# 188         14454                           OA_484  archived
# 189          5803               TEST_NOTIFICATIONS    active
# 190          4060  Search_OGUI24_Restored_Restored  archived
# 191          4026               Copy URL workspace    active
# 192          4028                        Notebooks    active
#
#            last_modified                  tag_names  favourite  watch
# 0    2024-09-30 11:13:02                         []      False  False
# ...

# %%
# get content of a workspace with workspace id

query = workspaces.list_contents(workspace_id)
query
# Out:
#   file_name size last_modified
# 0   folder1    -             -

# %%
#create new workspace with given name

workspaces.create_workspace("test_2024_04Nov")
# Out:
# INFO:root:Workspace Created !
# {'name': 'test_2024_04Nov',
#  'description': None,
#  'project_property': {'type': 'workspaces', 'labels': ''},
#  'created_time': '2024-11-04 09:48:30',
#  'last_modified': '2024-11-04 09:48:30',
#  'status': 1,
#  'creator': 1647238511,
#  'organisation': 1,
#  'id': 16579,
#  'tag_names': []}

# %%
# copy content from one workspace to another

workspaces.create_copy({sorce workspace id}, "source path", {destination workspace id}, "destination path")
# Out:
# Workspace_copy started, You will be notified upon completion.
# Copy Operation Successful!

# %%
# download from a workspace

workspaces.download_from_workspaces({workspace id}, "workspace source path", "destination local path", copy_workspace_path=True)
# Out:
# INFO:root:Download successful to path=/import

# %%
# upload from local to workspace

workspaces.upload_to_workspaces({workspace id}, "workspace destination path", "local source path")
# Out:
# INFO:root:Upload successful on workspace-id=16579.

# %%
# sync workspace data from workspace to local

workspaces.sync_data({workspace id}, "polly://{workspace sorce path}","local destination path")
# Out:
# INFO:root:Sync successful on workspace-id=16563.
